# %%
localaddress = "http://YOUR_IP_ADDRESS:PORT"

# %%
import papermill as pm

# 定义要运行的笔记本列表
notebooks = [
    'Catchweb_social.ipynb',
    'Catchweb_number.ipynb'
]

# 依次执行每个笔记本
for notebook in notebooks:
    pm.execute_notebook(
        notebook,
        notebook,  # 输出到原文件（会保留执行结果）
        parameters={},  # 可以传递参数
        log_output=False  # 不在当前笔记本中显示输出
    )

print("所有笔记本已执行完成！")
# Out:
# ...
# Executing:   0%|          | 0/5 [00:00<?, ?cell/s]
# 所有笔记本已执行完成！
